# %% [markdown]
# Time Series Analysis

# %%
import pandas as pd 
import matplotlib.pyplot as plt
source = 'C:/Users/Niranjan/Desktop/Dev/book_sales.csv'
df = pd.read_csv(source,index_col = 'Date',parse_dates=['Date']).drop('Paperback',axis =1)
df.head()
# Out:
#             Hardcover
# Date
# 2000-04-01        139
# 2000-04-02        128
# 2000-04-03        172
# 2000-04-04        139
# 2000-04-05        191

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
series_value = df.values

# %%
type(series_value)
# Out:
# numpy.ndarray

# %%
df.size
# Out:
# 30

# %%
df.describe()
# Out:
#         Hardcover
# count   30.000000
# mean   198.833333
# std     40.301522
# min    128.000000
# 25%    170.500000
# 50%    200.500000
# 75%    222.000000
# max    283.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_mean = df.rolling(window=5).mean()

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_mean.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ARDM
